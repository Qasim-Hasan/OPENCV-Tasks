# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Library from open cv
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
#COVERTING bgr to rgb
fix_img= cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
#as it does not show error if image path is wrong if NoneType than path is wrong
#transform image to numpy array in open cv automatically
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
# MATPLOT LIB COLOR ORDER ---> RED GREEN BLUE
# OPEN CV order -----> BLUE GREEN RED
plt.imshow(img)

# %%
# convert the image as gray scale in opencv
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
# it take the opposite       (1950,1300) 
# no distortion in color channels
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 1560, 3)

# %%
260*5
# Out:
# 1300

# %%
new_img = cv2.flip(fix_img,-1)

# %%
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
#save files images
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
#How much blank canvas space i can use in jupyter notebook can canvas size
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
